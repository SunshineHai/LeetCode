# %%
my_list = [1, 2, 3, 4, 5]
my_list
# Out:
# [1, 2, 3, 4, 5]

# %%
my_list.append(10)
my_list
# Out:
# [1, 2, 3, 4, 5, 10]

# %% [markdown]
# ## zip() 函数
#
# 在多个迭代器上并行迭代，从每个迭代器返回一个数据项组成元组。

# %%
[xv if c else yv
 for c, xv, yv in zip(condition, x, y)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11740/402449162.py in <module>
#       1 [xv if c else yv
# ----> 2  for c, xv, yv in zip(condition, x, y)]
#
# NameError: name 'condition' is not defined

# %%
for item in zip([1, 2, 3], ['sugar', 'spice', 'everything nice']):
...     print(item)
# Out:
# (1, 'sugar')
# (2, 'spice')
# (3, 'everything nice')

# %% [markdown]
# ## 画误差图
#
# 行 ：模型
# </br>
# 列 ： 不同评价指标

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 3)
y = np.arange(0, 10, 3)
print(x)
plt.plot(x, y, '*g--')
plt.show()
# Out:
# [0 3 6 9]

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

x = np.arange(0, 10, 3)
y1 = x
y2 = x**2

# 正常显示中文
from pylab import mpl
mpl.rcParams['font.sans-serif'] = ['SimHei']

plt.xlabel('自变量')   # 若是使用 汉字，则显示出错
plt.ylabel('因变量')
plt.plot(x, y1, '*g--', y2, '^b-')
plt.legend(['y=x', '$y=x^2$'], loc='upper right')  # 显示每条线段的解释， $$ 里是 LaTeX语句
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

def show_error(x_name:list, precision:list, recall:list, f1:list, AUC:list, path):
    plt.plot(x_name, precision, 'or-', recall, '^g-', f1, '*b-', AUC, '.y-.')
    plt.legend(['precision', 'recall', 'f1', 'AUC'], loc='upper right')
    plt.savefig(path, dpi=300)
    plt.show()
    pass

x_name = ['model1', 'model2', 'model3', 'model4']

y1 = [0.5, 0.6, 0.8, 0.9]
y2 = [0.6, 0.6, 0.85, 0.92]
y3 = [0.7, 0.66, 0.82, 0.91]
y4 = [0.8, 0.7, 0.82, 0.84, 0.93]
show_error(x_name,y1 ,y2 ,y3 , y4, r'test.png')

# %% [markdown]
# ## 支持向量机的应用

# %%
 from sklearn import svm
X = [[0, 0], [1, 1]]
y = [0, 1]
clf = svm.SVC()
clf.fit(X, y)
# Out:
# SVC()

# %% [markdown]
# ## str

# %%
my_str = "(3 - 5) * (6 + 17 * 4) / 3"
my_str.isspace()
# Out:
# False

# %%
str1 = "      "
str1.isspace()   # str 中有一个或多个空格则返回True,否则 返回 False
# Out:
# True
